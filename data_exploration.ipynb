# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import SimpleITK as sitk
import os

# %matplotlib inline

# %%
def mhd_to_array(path):
    """
    Read an *.mhd file stored in path and return it as a numpy array.
    """
    return sitk.GetArrayFromImage(sitk.ReadImage(path, sitk.sitkFloat32))

# %%
root = "..\\datasets\\CAMUS\\training"

# %%
sample_name = 'patient0001\\patient0001_2CH_ED'

image = mhd_to_array(os.path.join(root, sample_name + '.mhd'))
mask = mhd_to_array(os.path.join(root, sample_name + '_gt.mhd'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14092/2927401954.py in <module>
#       1 sample_name = 'patient0001\\patient0001_2CH_ED'
#       2
# ----> 3 image = mhd_to_array(os.path.join(root, sample_name + '.mhd'))
#       4 mask = mhd_to_array(os.path.join(root, sample_name + '_gt.mhd'))
#
# NameError: name 'mhd_to_array' is not defined

# %%
plt.imshow(mask[0])
